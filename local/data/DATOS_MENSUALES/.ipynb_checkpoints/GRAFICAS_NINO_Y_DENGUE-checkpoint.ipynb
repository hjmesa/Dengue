# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df_mn = pd.read_csv("PROMEDIOS_MENSUALES.csv")
df_mn.head()

# def str_zfill(num):
#     return str(num).zfill(2) 

# # dnin["time"] = dnin["YR"].map(str) + "-" + dnin["MON"].map(str_zfill)
# # dnin.tail()

# df_mnor['Year-month'] = df_mnor['YEAR'].map(str) + "-" + df_mnor['MONTH'].map(str_zfill)

# df_mnor.head()
# Out:
#    MONTH    PTPM_CON  HRA2_AUT_60_MEAN  HRA2_AUT_60_AMAX  HRA2_AUT_60_AMIN  \
# 0      1   73.807692         72.089920         97.076923         44.076923
# 1      2   72.041667         71.596735         97.666667         43.666667
# 2      3  113.025000         73.841829         97.500000         43.666667
# 3      4  188.416667         76.527702         98.250000         45.916667
# 4      5  162.275000         76.976199         98.500000         47.750000
#
#    TA2_AUT_60_MEAN  TA2_AUT_60_AMAX  TA2_AUT_60_AMIN    NINO1+2      ANOM  \
# 0        24.987338        32.907692        18.507692  24.573846  0.063077
# 1        25.025526        32.916667        18.716667  26.171667  0.041667
# 2        24.888222        33.350000        18.658333  26.663333  0.045833
# 3        24.501213        32.950000        19.016667  25.728333  0.149167
# 4        24.580349        32.950000        18.391667  24.594167  0.331667
#
#        NINO3    ANOM.1      NINO4    ANOM.2    NINO3.4    ANOM.3  \
# ...

# %%
X =df_mnor[['YEAR', 'PTPM_CON', 'HRA2_AUT_60_MEAN', 'HRA2_AUT_60_AMAX',
       'HRA2_AUT_60_AMIN', 'TA2_AUT_60_MEAN', 'TA2_AUT_60_AMAX',
       'TA2_AUT_60_AMAX', 'NINO1+2', 'ANOM', 'NINO3', 'ANOM.1', 'NINO4',
       'ANOM.2', 'NINO3.4', 'ANOM.3', 'CONFIRMED_CASES', 'ALL_CASES', 'Year-month']]

# %%
x = X['Year-month']

# Temperatura
y1 =  X['TA2_AUT_60_MEAN']
y12 = X['TA2_AUT_60_AMAX']
y13 = X['TA2_AUT_60_AMIN']
# humedad
y2 = X['HRA2_AUT_60_MEAN']

#Precipitación
y3 = X['PTPM_CON']


n1 = X['ANOM']
n2 = X['ANOM.1']
n4 = X['ANOM.2']
n3 = X['ANOM.3']


nt1 = X['NINO1+2']
nt2 = X['NINO3']
nt4 = X['NINO4']
nt3 = X['NINO3.4']


dg1 = X['CONFIRMED_CASES']
dg2 = X['ALL_CASES']

# %%
# ax = plt.figure(figsize=(10, 7))
# plt.plot(x, y1 , '-o',linewidth=2.0, label = "MEDIA")
# # plt.title('Desfases nino vs dengue')
# plt.ylabel('Temperatura',  fontsize=15 )
# plt.title('Casos confirmados-Temperatura',  fontsize=15 )
# plt.xlabel('Desfase (semanas)', fontsize=20)
# plt.plot(x, y12 , '-o',linewidth=2.0, label = "MAXIMA")
# plt.plot(x, y13 , '-o',linewidth=2.0, label = "MINIMA")
# # plt.title('Desfases nino vs dengue')
# plt.legend(loc="upper right")


# # fig, ax =plt.subplots(1)
# # # Plot y1 vs x in blue on the left vertical axis.
# # plt.xlabel("Año-mes")
# # plt.ylabel("Casos dengue confirmados", color="b")
# # plt.tick_params(axis="y", labelcolor="b")
# # plt.plot(x1, dg1, "b-")
# # plt.xticks(rotation=90)
# # for ind, label in enumerate(ax.get_xticklabels()):
# #     if ind % 30 == 0:  # every 10th label is kept
# #         label.set_visible(True)
# #     else:
# #         label.set_visible(False)
# # plt.locator_params(axis='x', nbins=30)
# # plt.tight_layout()


# plt.twinx()
# plt.ylabel("Casos confirmados", color="r")
# plt.tick_params(axis="y", labelcolor="r")
# plt.plot(x, dg1, "r-")
# plt.show()

# %%
# plt.figure(figsize=(12, 9), dpi = 300)

# # plt.title('Desfases nino vs dengue')
# plt.ylabel('Correlación',  fontsize=15 )
# plt.title('Correlación Casos confirmados-Niño',  fontsize=15 )
# plt.xlabel('Desfase (semanas)', fontsize=20)
# plt.plot(x, n1 , '-o',linewidth=2.0, label = "ANOM")
# plt.plot(x, n2 , '-o',linewidth=2.0, label = "ANOM1")
# plt.plot(x, n3, '-o',linewidth=2.0, label = "ANOM2")
# plt.plot(x, n4 , '-o',linewidth=2.0, label = "ANOM3")
# # plt.plot(x, tni1 , '-o',linewidth=2.0, label = "NINO1+2")
# # plt.plot(x, tni3 , '-o',linewidth=2.0, label = "NINO3")
# # plt.plot(x, tni5 , '-o',linewidth=2.0, label = "NINO4")
# # plt.plot(x, tni7 , '-o',linewidth=2.0, label = "NINO3+4")
# plt.twinx()
# plt.ylabel("Casos confirmados", color="r")
# plt.tick_params(axis="y", labelcolor="r")
# plt.plot(x, dg1, "r-")
# plt.show()
# # plt.title('Desfases nino vs dengue')
# plt.legend(loc="upper left")

# %%
import warnings
warnings.filterwarnings("ignore")

x1 = x
############# todos dengue - anomalia 12 ################
fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Anom_Niño_12", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, n1, "r-")
plt.show()

############## tempera - niño 3##############

fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Anom_Niño_3", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, n2, "r-")
plt.show()


###################tempera - anomalia 34##############

fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Anom_Niño_34", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, n3, "r-")
plt.show()

###################tempera - anomalia 4##############
fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)

for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Anom_Niño_4", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, n4, "r-")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

x1 = x
############# todos dengue - anomalia 12 ################
fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Niño_12", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, nt1, "r-")
plt.show()

############## tempera - niño 3##############

fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Niño_3", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, nt2, "r-")
plt.show()


###################tempera - anomalia 34##############

fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)
for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Anom_Niño_34", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, nt3, "r-")
plt.show()

###################tempera - anomalia 4##############
fig, ax =plt.subplots(1)
# Plot y1 vs x in blue on the left vertical axis.
plt.xlabel("Año-mes")
plt.ylabel("Casos dengue confirmados", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x1, dg1, "b-")
plt.xticks(rotation=90)

for ind, label in enumerate(ax.get_xticklabels()):
    if ind % 30 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
plt.locator_params(axis='x', nbins=30)
plt.tight_layout()


plt.twinx()
plt.ylabel("Anom_Niño_4", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x1, nt4, "r-")
plt.show()

# %%
df_comp_weekly_norm = pd.read_csv("DATOS_SEMANALES_NORMALIZADOS_CALI.csv")

# %%
df_comp_weekly = pd.read_csv('DATOS_SEMANALES_ESTACIONES_NINO.csv')
df_comp_monthly = pd.read_csv('DATOS_MENSUALES_ESTACIONES_NINO.csv')
df_comp_monthly = df_comp_monthly.iloc[12:-2,:]
df_comp_weekly = df_comp_weekly.iloc[52:-5,:]
df_comp_monthly = df_comp_monthly.interpolate()
df_comp_weekly = df_comp_weekly.interpolate()

# %%
df_mnor = df_comp_monthly

def str_zfill(num):
    return str(num).zfill(2) 

# dnin["time"] = dnin["YR"].map(str) + "-" + dnin["MON"].map(str_zfill)
# dnin.tail()

df_mnor['Year-month'] = df_mnor['YEAR'].map(str) + "-" + df_mnor['MONTH'].map(str_zfill)

df_mnor
# Out:
#      YEAR  MONTH  PTPM_CON  HRA2_AUT_60_MEAN  HRA2_AUT_60_AMAX  \
# 12   2007      1      59.4         71.353495              98.0
# 13   2007      2       2.4         66.482861              98.0
# 14   2007      3     185.4         73.762739              98.0
# 15   2007      4     196.6         77.642276              99.0
# 16   2007      5     145.4         78.096730              99.0
# 17   2007      6      27.5         72.838340              99.0
# 18   2007      7      45.4         69.787500              98.0
# 19   2007      8     103.4         72.602195              98.0
# 20   2007      9      17.9         68.456860              97.0
# 21   2007     10     113.2         76.251412              99.0
# 22   2007     11     131.5         76.072626              99.0
# 23   2007     12      68.0         79.128388              99.0
# 24   2008      1     136.5         75.395894              98.0
# 25   2008      2     168.5         74.923191              99.0
# ...

# %%
df_mnor.describe()
# Out:
#               YEAR       MONTH    PTPM_CON  HRA2_AUT_60_MEAN  \
# count   144.000000  144.000000  144.000000        144.000000
# mean   2012.500000    6.500000  102.170833         73.268198
# std       3.464102    3.464102   67.371848          4.047292
# min    2007.000000    1.000000    2.400000         63.649616
# 25%    2009.750000    3.750000   45.100000         70.273164
# 50%    2012.500000    6.500000   98.900000         73.967615
# 75%    2015.250000    9.250000  145.800000         76.272083
# max    2018.000000   12.000000  371.100000         82.436232
#
#        HRA2_AUT_60_AMAX  HRA2_AUT_60_AMIN  TA2_AUT_60_MEAN  TA2_AUT_60_AMAX  \
# count        144.000000        144.000000       144.000000       144.000000
# mean          97.631944         41.041667        24.396708        33.112500
# std            1.422824          8.900283         3.040631         3.237412
# min           93.000000          3.000000         1.520000         6.800000
# ...

# %%
 X = df_mnor[['YEAR', 'PTPM_CON', 'HRA2_AUT_60_MEAN', 'HRA2_AUT_60_AMAX',
       'HRA2_AUT_60_AMIN', 'TA2_AUT_60_MEAN', 'TA2_AUT_60_AMAX',
       'TA2_AUT_60_AMIN', 'NINO1+2', 'ANOM', 'NINO3', 'ANOM.1', 'NINO4',
       'ANOM.2', 'NINO3.4', 'ANOM.3', 'CONFIRMED_CASES', 'ALL_CASES', 'Year-month']]

# %%
x = X['Year-month']

# Temperatura
y1 =  X['TA2_AUT_60_MEAN']
y12 = X['TA2_AUT_60_AMAX']
y13 = X['TA2_AUT_60_AMIN']
# # humedad
y2 = X['HRA2_AUT_60_MEAN']
y21 = X['HRA2_AUT_60_AMAX']
y22 = X['HRA2_AUT_60_AMIN']
#Precipitación
y3 = X['PTPM_CON']


# n1 = X['ANOM']
# n2 = X['ANOM.1']
# n4 = X['ANOM.2']
# n3 = X['ANOM.3']


# nt1 = X['NINO1+2']
# nt2 = X['NINO3']
# nt4 = X['NINO4']
# nt3 = X['NINO3.4']


dg1 = X['CONFIRMED_CASES']
dg2 = X['ALL_CASES']

# %%
# 
vmin = 15
vmax = 37
for  j in y12:
    if j < vmin or j > vmax :
        print(j)
# Out:
# 6.8
# 49.2
# 49.2

# %%
# 
plt.figure(figsize=(10, 7))
plt.plot(x, y1 , '-o',linewidth=2.0, label = "MEDIA")
# plt.title('Desfases nino vs dengue')
plt.ylabel('Correlación',  fontsize=15 )
# plt.title('Temperatura',  fontsize=15 )
plt.xlabel('Desfase (meses)', fontsize=20)
plt.plot(x, y12 , '-o',linewidth=2.0, label = "MAXIMA")
plt.plot(x, y13 , '-o',linewidth=2.0, label = "MINIMA")
# plt.title('Desfases nino vs dengue')
plt.legend(loc="upper left")

# %%
# 
plt.figure(figsize=(10, 7))
plt.plot(x, y2 , '-o',linewidth=2.0, label = "MEDIA")
# plt.title('Desfases nino vs dengue')
plt.ylabel('Humedadad',  fontsize=15 )
# plt.title('Temperatura',  fontsize=15 )
plt.xlabel('tiempo', fontsize=20)
plt.plot(x, y21 , '-o',linewidth=2.0, label = "MAXIMA")
plt.plot(x, y22 , '-o',linewidth=2.0, label = "MINIMA")
# plt.title('Desfases nino vs dengue')
plt.legend(loc="upper left")

# %%
plt.figure(figsize=(10, 7))
plt.plot(x, y3 , '-o',linewidth=2.0, label = "MEDIA")
# plt.title('Desfases nino vs dengue')
plt.ylabel('Precipitación',  fontsize=15 )
# plt.title('Temperatura',  fontsize=15 )
# plt.xlabel('tiempo', fontsize=20)
# plt.plot(x, y21 , '-o',linewidth=2.0, label = "MAXIMA")
# plt.plot(x, y22 , '-o',linewidth=2.0, label = "MINIMA")
# plt.title('Desfases nino vs dengue')
plt.legend(loc="upper left")

# %% [markdown]
# # Semana

# %%
df_mnor = df_comp_weekly

def str_zfill(num):
    return str(num).zfill(2) 

# dnin["time"] = dnin["YR"].map(str) + "-" + dnin["MON"].map(str_zfill)
# dnin.tail()

df_mnor['Year-week'] = df_mnor['YEAR'].map(str) + "-" + df_mnor['WEEK'].map(str_zfill)

df_mnor.head()
# Out:
#     YEAR  WEEK  PTPM_CON  HRA2_AUT_60_MEAN  HRA2_AUT_60_AMAX  \
# 52  2007     1       0.4         68.517857              90.0
# 53  2007     2      15.2         71.690476              96.0
# 54  2007     3      37.0         73.666667              98.0
# 55  2007     4       6.8         72.750000              96.0
# 56  2007     5       0.0         67.190476              90.0
#
#     HRA2_AUT_60_AMIN  TA2_AUT_60_MEAN  TA2_AUT_60_AMAX  TA2_AUT_60_AMIN  \
# 52              49.0        25.931737             32.2             20.7
# 53              46.0        25.748193             32.5             20.6
# 54              42.0        25.464286             33.8             20.0
# 55              46.0        25.315476             33.0             20.0
# 56              41.0        26.147024             33.5             20.4
#
#     NINO1+2  ...   NINO3  ANOM.1   NINO4  ANOM.2  NINO3.4  ANOM.3  \
# 52   24.990  ...  26.500   0.870  28.930   0.630   27.260    0.69
# ...

# %%
# Temperatura 

count =(df_mnor['HRA2_AUT_60_MEAN'] < df_mnor['HRA2_AUT_60_MEAN'].mean()) 
df_mnor.loc[count]
# print(df_count)
# Out:
#      YEAR  WEEK  PTPM_CON  HRA2_AUT_60_MEAN  HRA2_AUT_60_AMAX  \
# 52   2007     1       0.4         68.517857         90.000000
# 53   2007     2      15.2         71.690476         96.000000
# 55   2007     4       6.8         72.750000         96.000000
# 56   2007     5       0.0         67.190476         90.000000
# 57   2007     6       0.0         65.275449         91.000000
# 58   2007     7       2.4         68.160714         98.000000
# 59   2007     8       0.0         67.660714         96.000000
# 60   2007     9       6.9         64.266667         90.000000
# 62   2007    11      47.3         70.898148         95.000000
# 75   2007    24       8.9         71.357143         94.000000
# 76   2007    25       7.3         71.340136         94.000000
# 77   2007    26       0.8         68.589286         95.000000
# 78   2007    27       0.5         66.177215         93.000000
# 79   2007    28      22.3         69.888199         97.000000
# ...

# %%
#

# %%
 X = df_mnor[['YEAR', 'PTPM_CON', 'HRA2_AUT_60_MEAN', 'HRA2_AUT_60_AMAX',
       'HRA2_AUT_60_AMIN', 'TA2_AUT_60_MEAN', 'TA2_AUT_60_AMAX',
       'TA2_AUT_60_AMIN', 'NINO1+2', 'ANOM', 'NINO3', 'ANOM.1', 'NINO4',
       'ANOM.2', 'NINO3.4', 'ANOM.3', 'CONFIRMED_CASES', 'ALL_CASES', 'Year-week']]

# %%
x = X['Year-week']

# Temperatura
y1 =  X['TA2_AUT_60_MEAN']
y12 = X['TA2_AUT_60_AMAX']
y13 = X['TA2_AUT_60_AMIN']
# # humedad
y2 = X['HRA2_AUT_60_MEAN']
y21 = X['HRA2_AUT_60_AMAX']
y22 = X['HRA2_AUT_60_AMIN']
#Precipitación
y3 = X['PTPM_CON']


# n1 = X['ANOM']
# n2 = X['ANOM.1']
# n4 = X['ANOM.2']
# n3 = X['ANOM.3']


# nt1 = X['NINO1+2']
# nt2 = X['NINO3']
# nt4 = X['NINO4']
# nt3 = X['NINO3.4']


dg1 = X['CONFIRMED_CASES']
dg2 = X['ALL_CASES']

# %%
plt.figure(figsize=(20,10))
plt.plot(x, y1 , '-o',linewidth=2.0, label = "MEDIA")
# plt.title('Desfases nino vs dengue')
plt.ylabel('Temperatura',  fontsize=15 )
# plt.title('Temperatura',  fontsize=15 )
plt.xlabel('semanas', fontsize=20)
plt.plot(x, y12 , '-o',linewidth=2.0, label = "MAXIMA")
plt.plot(x, y13 , '-o',linewidth=2.0, label = "MINIMA")
# plt.title('Desfases nino vs dengue')
plt.legend(loc="upper left")

# %%
plt.figure(figsize=(10, 7))
plt.plot(x, y2 , '-o',linewidth=2.0, label = "MEDIA")
# plt.title('Desfases nino vs dengue')
plt.ylabel('Humedadad',  fontsize=15 )
# plt.title('Temperatura',  fontsize=15 )
plt.xlabel('tiempo - semana', fontsize=20)
plt.plot(x, y21 , '-o',linewidth=2.0, label = "MAXIMA")
plt.plot(x, y22 , '-o',linewidth=2.0, label = "MINIMA")
# plt.title('Desfases nino vs dengue')
plt.legend(loc="upper left")

# %%
plt.figure(figsize=(10, 7))
plt.plot(x, y3 , '-o',linewidth=2.0, label = "MEDIA")
# plt.title('Desfases nino vs dengue')
plt.ylabel('Precipitación',  fontsize=15 )
# plt.title('Temperatura',  fontsize=15 )
plt.xlabel('tiempo-semana', fontsize=20)
# plt.plot(x, y21 , '-o',linewidth=2.0, label = "MAXIMA")
# plt.plot(x, y22 , '-o',linewidth=2.0, label = "MINIMA")
# plt.title('Desfases nino vs dengue')
plt.legend(loc="upper left")
